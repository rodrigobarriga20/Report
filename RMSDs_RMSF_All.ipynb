# %%
import MDAnalysis as mda
import xdrlib
from MDAnalysis.analysis import rms
import matplotlib.pyplot as plt
from MDAnalysis.analysis import align
from tqdm import tqdm
import numpy as np
import nglview as nv
import time
import MDAnalysis.transformations as trans
# Out:
# /home/ralves/anaconda3/lib/python3.11/site-packages/MDAnalysis/topology/TPRParser.py:161: DeprecationWarning: 'xdrlib' is deprecated and slated for removal in Python 3.13
#   import xdrlib

# %%
# 3RQ3 - red
u_3rq3 = mda.Universe("3RQ3/md.gro", "3RQ3/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_3rq3 = u_3rq3.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_3rq3.trajectory[0] # set to the first frame
rmsfer_3rq3_Chain_A = rms.RMSF(u_3rq3.select_atoms("index 0:1038 and name CA"), verbose=True).run()
rmsfer_3rq3_Chain_B = rms.RMSF(u_3rq3.select_atoms("index 1039:2078 and name CA"), verbose=True).run()
rmsd_3rq3_Chain_A = rms.RMSD(u_3rq3.select_atoms("index 0:1038 and name CA"), verbose=True).run()
rmsd_3rq3_Chain_B = rms.RMSD(u_3rq3.select_atoms("index 1039:2078 and name CA"), verbose=True).run() # Convert time from picoseconds to nanoseconds
time_ns_3rq3_A = rmsd_3rq3_Chain_A.results.rmsd[:, 1] / 1000
time_ns_3rq3_B = rmsd_3rq3_Chain_B.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 3Q0H - blue #006a8b
u_3q0h = mda.Universe("3Q0H/md.gro", "3Q0H/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_3q0h = u_3q0h.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_3q0h.trajectory[0] # set to the first frame
rmsfer_3q0h_Chain_A = rms.RMSF(u_3q0h.select_atoms("index 0:1056 and name CA"), verbose=True).run()
rmsfer_3q0h_Chain_B = rms.RMSF(u_3q0h.select_atoms("index 1057:2093 and name CA"), verbose=True).run() 
rmsd_3q0h_Chain_A = rms.RMSD(u_3q0h.select_atoms("index 0:1056 and name CA"), verbose=True).run()
rmsd_3q0h_Chain_B = rms.RMSD(u_3q0h.select_atoms("index 1057:2093 and name CA"), verbose=True).run() 
time_ns_3q0h_A = rmsd_3q0h_Chain_A.results.rmsd[:, 1] / 1000
time_ns_3q0h_B = rmsd_3q0h_Chain_B.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 3UDW - green
u_3udw = mda.Universe("3UDW/md.gro", "3UDW/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_3udw = u_3udw.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_3udw.trajectory[0] # set to the first frame
rmsfer_3udw_Chain_A = rms.RMSF(u_3udw.select_atoms("index 0:1020 and name CA"), verbose=True).run()
rmsfer_3udw_Chain_B = rms.RMSF(u_3udw.select_atoms("index 1021:2023 and name CA"), verbose=True).run() 
rmsd_3udw_Chain_A = rms.RMSD(u_3udw.select_atoms("index 0:1020 and name CA"), verbose=True).run()
rmsd_3udw_Chain_B = rms.RMSD(u_3udw.select_atoms("index 1021:2023 and name CA"), verbose=True).run() 
time_ns_3udw_A = rmsd_3udw_Chain_A.results.rmsd[:, 1] / 1000
time_ns_3udw_B = rmsd_3udw_Chain_B.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 3UCR - orange
u_3ucr = mda.Universe("3UCR/md.gro", "3UCR/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_3ucr = u_3ucr.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_3ucr.trajectory[0] # set to first frame
rmsfer_3ucr_Chain_A = rms.RMSF(u_3ucr.select_atoms("index 0:1030 and name CA"), verbose=True).run()
rmsfer_3ucr_Chain_B = rms.RMSF(u_3ucr.select_atoms("index 1031:2061 and name CA"), verbose=True).run() 
rmsfer_3ucr_Chain_C = rms.RMSF(u_3ucr.select_atoms("index 2062:3120 and name CA"), verbose=True).run() 
rmsfer_3ucr_Chain_D = rms.RMSF(u_3ucr.select_atoms("index 3121:4144 and name CA"), verbose=True).run()
rmsd_3ucr_Chain_A = rms.RMSD(u_3ucr.select_atoms("index 0:1030 and name CA"), verbose=True).run()
rmsd_3ucr_Chain_B = rms.RMSD(u_3ucr.select_atoms("index 1031:2061 and name CA"), verbose=True).run() 
rmsd_3ucr_Chain_C = rms.RMSD(u_3ucr.select_atoms("index 2062:3120 and name CA"), verbose=True).run() 
rmsd_3ucr_Chain_D = rms.RMSD(u_3ucr.select_atoms("index 3121:4144 and name CA"), verbose=True).run()
time_ns_3ucr_A = rmsd_3ucr_Chain_A.results.rmsd[:, 1] / 1000
time_ns_3ucr_B = rmsd_3ucr_Chain_B.results.rmsd[:, 1] / 1000
time_ns_3ucr_C = rmsd_3ucr_Chain_C.results.rmsd[:, 1] / 1000
time_ns_3ucr_D = rmsd_3ucr_Chain_D.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 5V52 - light brown #b27100
u_5v52 = mda.Universe("5V52/md.gro", "5V52/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_5v52 = u_5v52.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_5v52.trajectory[0] # set to the first frame
rmsfer_5v52_Chain_A = rms.RMSF(u_5v52.select_atoms("index 0:967 and name CA"), verbose=True).run()
rmsfer_5v52_Chain_B = rms.RMSF(u_5v52.select_atoms("index 968:1951 and name CA"), verbose=True).run() 
rmsd_5v52_Chain_A = rms.RMSD(u_5v52.select_atoms("index 0:967 and name CA"), verbose=True).run()
rmsd_5v52_Chain_B = rms.RMSD(u_5v52.select_atoms("index 968:1951 and name CA"), verbose=True).run()
time_ns_5v52_A = rmsd_5v52_Chain_A.results.rmsd[:, 1] / 1000
time_ns_5v52_B = rmsd_5v52_Chain_B.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 7VYT - grey
u_7vyt = mda.Universe("7VYT/md.gro", "7VYT/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_7vyt = u_7vyt.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_7vyt.trajectory[0] # set to the first frame
rmsfer_7vyt_Chain_A = rms.RMSF(u_7vyt.select_atoms("index 0:1022 and name CA"), verbose=True).run()
rmsfer_7vyt_Chain_C = rms.RMSF(u_7vyt.select_atoms("index 5622:6636 and name CA"), verbose=True).run() #Aqui é colocar menos 1 do que se vê, 6637 - 1
rmsd_7vyt_Chain_A = rms.RMSD(u_7vyt.select_atoms("index 0:1022 and name CA"), verbose=True).run()
rmsd_7vyt_Chain_C = rms.RMSD(u_7vyt.select_atoms("index 5622:6636 and name CA"), verbose=True).run() 
time_ns_7vyt_A = rmsd_7vyt_Chain_A.results.rmsd[:, 1] / 1000
time_ns_7vyt_C = rmsd_7vyt_Chain_C.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 8SZY - turquoise #01ab82
u_8szy = mda.Universe("8SZY/md.gro", "8SZY/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_8szy = u_8szy.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_8szy.trajectory[0] # set to the first frame
rmsfer_8szy_Chain_E = rms.RMSF(u_8szy.select_atoms("index 17020:18019 and name CA"), verbose=True).run()
rmsfer_8szy_Chain_J = rms.RMSF(u_8szy.select_atoms("index 18020:19022 and name CA"), verbose=True).run() #Aqui é colocar menos 1 do que se vê, 6637 - 1
rmsd_8szy_Chain_E = rms.RMSD(u_8szy.select_atoms("index 17020:18019 and name CA"), verbose=True).run()
rmsd_8szy_Chain_J = rms.RMSD(u_8szy.select_atoms("index 18020:19022 and name CA"), verbose=True).run() 
time_ns_8szy_E = rmsd_8szy_Chain_E.results.rmsd[:, 1] / 1000
time_ns_8szy_J = rmsd_8szy_Chain_J.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 8JEO - #6f5602 (pink)
u_8jeo = mda.Universe("8JEO/md.gro", "8JEO/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_8jeo = u_8jeo.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_8jeo.trajectory[0] # set to the first frame
rmsfer_8jeo_Chain_A = rms.RMSF(u_8jeo.select_atoms("index 0:1030 and name CA"), verbose=True).run() 
rmsfer_8jeo_Chain_D = rms.RMSF(u_8jeo.select_atoms("index 5439:6478 and name CA"), verbose=True).run()
rmsd_8jeo_Chain_A = rms.RMSD(u_8jeo.select_atoms("index 0:1030 and name CA"), verbose=True).run() 
rmsd_8jeo_Chain_D = rms.RMSD(u_8jeo.select_atoms("index 5439:6478 and name CA"), verbose=True).run()
time_ns_8jeo_A = rmsd_8jeo_Chain_A.results.rmsd[:, 1] / 1000
time_ns_8jeo_D = rmsd_8jeo_Chain_D.results.rmsd[:, 1] / 1000
# Out:
# ...
#   0%|          | 0/50001 [00:00<?, ?it/s]

# %%
# 8JEN - #f46652 (salmon)
u_8jen = mda.Universe("8JEN/md.gro", "8JEN/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_8jen = u_8jen.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_8jen.trajectory[0] # set to the first frame
rmsfer_8jen_Chain_G = rms.RMSF(u_8jen.select_atoms("index 12739:13769 and name CA"), verbose=True).run() 
rmsfer_8jen_Chain_H = rms.RMSF(u_8jen.select_atoms("index 13770:14800 and name CA"), verbose=True).run()
rmsfer_8jen_Chain_I = rms.RMSF(u_8jen.select_atoms("index 14801:15831 and name CA"), verbose=True).run()
rmsfer_8jen_Chain_J = rms.RMSF(u_8jen.select_atoms("index 15832:16844 and name CA"), verbose=True).run()
rmsd_8jen_Chain_G = rms.RMSD(u_8jen.select_atoms("index 12739:13769 and name CA"), verbose=True).run() 
rmsd_8jen_Chain_H = rms.RMSD(u_8jen.select_atoms("index 13770:14800 and name CA"), verbose=True).run()
rmsd_8jen_Chain_I = rms.RMSD(u_8jen.select_atoms("index 14801:15831 and name CA"), verbose=True).run()
rmsd_8jen_Chain_J = rms.RMSD(u_8jen.select_atoms("index 15832:16844 and name CA"), verbose=True).run()
time_ns_8jen_G = rmsd_8jen_Chain_G.results.rmsd[:, 1] / 1000
time_ns_8jen_H = rmsd_8jen_Chain_H.results.rmsd[:, 1] / 1000
time_ns_8jen_I = rmsd_8jen_Chain_I.results.rmsd[:, 1] / 1000
time_ns_8jen_J = rmsd_8jen_Chain_J.results.rmsd[:, 1] / 1000

# %%
# 8JEl - #af97fa (purple)
u_8jel = mda.Universe("8JEL/md.gro", "8JEL/final.xtc") # Universe (.gro file, trajectory .xtc file)
calphas_8jel = u_8jel.select_atoms("name CA") # Choice of alfa-Carbon atoms
u_8jel.trajectory[0] # set to the first frame
rmsfer_8jel_Chain_C = rms.RMSF(u_8jel.select_atoms("index 4239:5287 and name CA"), verbose=True).run() 
rmsfer_8jel_Chain_F = rms.RMSF(u_8jel.select_atoms("index 9526:10575 and name CA"), verbose=True).run()
rmsfer_8jel_Chain_I = rms.RMSF(u_8jel.select_atoms("index 14719:15758 and name CA"), verbose=True).run()
rmsfer_8jel_Chain_L = rms.RMSF(u_8jel.select_atoms("index 19963:20993 and name CA"), verbose=True).run()
rmsd_8jel_Chain_C = rms.RMSD(u_8jel.select_atoms("index 4239:5287 and name CA"), verbose=True).run() 
rmsd_8jel_Chain_F = rms.RMSD(u_8jel.select_atoms("index 9526:10575 and name CA"), verbose=True).run()
rmsd_8jel_Chain_I = rms.RMSD(u_8jel.select_atoms("index 14719:15758 and name CA"), verbose=True).run()
rmsd_8jel_Chain_L = rms.RMSD(u_8jel.select_atoms("index 19963:20993 and name CA"), verbose=True).run()
time_ns_8jel_C = rmsd_8jel_Chain_C.results.rmsd[:, 1] / 1000
time_ns_8jel_F = rmsd_8jel_Chain_F.results.rmsd[:, 1] / 1000
time_ns_8jel_I = rmsd_8jel_Chain_I.results.rmsd[:, 1] / 1000
time_ns_8jel_L = rmsd_8jel_Chain_L.results.rmsd[:, 1] / 1000

# %%
# RMSDs
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

#plt.plot(time_ns_3rq3_B, rmsd_3rq3_Chain_B.results.rmsd[:,2], color="red", label="3RQ3")
#plt.plot(time_ns_3rq3_A, rmsd_3rq3_Chain_A.results.rmsd[:,2], color="red")

# Apply smoothing using convolution
window_size = 500
smooth_data_3RQ3_B = np.convolve(rmsd_3rq3_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3RQ3_A = np.convolve(rmsd_3rq3_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
# Plot smoothed data
plt.plot(time_ns_3rq3_B, smooth_data_3RQ3_B, lw=5, color="red", label="3RQ3")
plt.plot(time_ns_3rq3_A, smooth_data_3RQ3_A, lw=5, color="red")

#plt.plot(time_ns_3q0h_A, rmsd_3q0h_Chain_A.results.rmsd[:,2], color="#006a8b", label="3Q0H")
#plt.plot(time_ns_3q0h_B, rmsd_3q0h_Chain_B.results.rmsd[:,2], color="#006a8b")

smooth_data_3Q0H_A = np.convolve(rmsd_3q0h_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3Q0H_B = np.convolve(rmsd_3q0h_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3q0h_A, smooth_data_3Q0H_A, lw=5, color="#006a8b", label="3Q0H")
plt.plot(time_ns_3q0h_B, smooth_data_3Q0H_B, lw=5, color="#006a8b")

#plt.plot(time_ns_3udw_A, rmsd_3udw_Chain_A.results.rmsd[:,2], color="green", label="3UDW")
#plt.plot(time_ns_3udw_B, rmsd_3udw_Chain_B.results.rmsd[:,2], color="green")

smooth_data_3UDW_A = np.convolve(rmsd_3udw_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UDW_B = np.convolve(rmsd_3udw_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3udw_A, smooth_data_3UDW_A, lw=5, color="green", label="3UDW")
plt.plot(time_ns_3udw_B, smooth_data_3UDW_B, lw=5, color="green")

#plt.plot(time_ns_3ucr_C, rmsd_3ucr_Chain_C.results.rmsd[:,2], color="orange", label="3UCR")
#plt.plot(time_ns_3ucr_D, rmsd_3ucr_Chain_D.results.rmsd[:,2], color="orange")
#plt.plot(time_ns_3ucr_B, rmsd_3ucr_Chain_B.results.rmsd[:,2], color="orange")
#plt.plot(time_ns_3ucr_A, rmsd_3ucr_Chain_A.results.rmsd[:,2], color="orange")

smooth_data_3UCR_C = np.convolve(rmsd_3ucr_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UCR_D = np.convolve(rmsd_3ucr_Chain_D.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UCR_B = np.convolve(rmsd_3ucr_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UCR_A = np.convolve(rmsd_3ucr_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3ucr_C, smooth_data_3UCR_C, lw=5, color="orange", label="3UCR")
plt.plot(time_ns_3ucr_D, smooth_data_3UCR_D, lw=5, color="orange")
plt.plot(time_ns_3ucr_B, smooth_data_3UCR_B, lw=5, color="orange")
plt.plot(time_ns_3ucr_A, smooth_data_3UCR_A, lw=5, color="orange")

#plt.plot(time_ns_5v52_A, rmsd_5v52_Chain_A.results.rmsd[:,2], color="#b27100", label="5V52")
#plt.plot(time_ns_5v52_B, rmsd_5v52_Chain_B.results.rmsd[:,2], color="#b27100")

smooth_data_5V52_A = np.convolve(rmsd_5v52_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_5V52_B = np.convolve(rmsd_5v52_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_5v52_A, smooth_data_5V52_A, lw=5, color="#b27100", label="5V52")
plt.plot(time_ns_5v52_B, smooth_data_5V52_B, lw=5, color="#b27100")

#plt.plot(time_ns_7vyt_A, rmsd_7vyt_Chain_A.results.rmsd[:,2], color="grey", label="7VYT")
#plt.plot(time_ns_7vyt_C, rmsd_7vyt_Chain_C.results.rmsd[:,2], color="grey")

smooth_data_7VYT_A = np.convolve(rmsd_7vyt_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_7VYT_C = np.convolve(rmsd_7vyt_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_7vyt_A, smooth_data_7VYT_A, lw=5, color="grey", label="7VYT")
plt.plot(time_ns_7vyt_C, smooth_data_7VYT_C, lw=5, color="grey")

#plt.plot(time_ns_8szy_E, rmsd_8szy_Chain_E.results.rmsd[:,2], color="#01ab82", label="8SZY")
#plt.plot(time_ns_8szy_J, rmsd_8szy_Chain_J.results.rmsd[:,2], color="#01ab82")

smooth_data_8SZY_E = np.convolve(rmsd_8szy_Chain_E.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8SZY_J = np.convolve(rmsd_8szy_Chain_J.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8szy_E, smooth_data_8SZY_E, lw=5, color="#01ab82", label="8SZY")
plt.plot(time_ns_8szy_J, smooth_data_8SZY_J, lw=5, color="#01ab82")

smooth_data_8JEO_A = np.convolve(rmsd_8jeo_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEO_D = np.convolve(rmsd_8jeo_Chain_D.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jeo_A, smooth_data_8JEO_A, lw=5, color="#6f5602", label="8JEO")
plt.plot(time_ns_8jeo_D, smooth_data_8JEO_D, lw=5, color="#6f5602")

smooth_data_8JEN_G = np.convolve(rmsd_8jen_Chain_G.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_H = np.convolve(rmsd_8jen_Chain_H.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_I = np.convolve(rmsd_8jen_Chain_I.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_J = np.convolve(rmsd_8jen_Chain_J.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jen_G, smooth_data_8JEN_G, lw=5, color="#f46652", label="8JEN")
plt.plot(time_ns_8jen_H, smooth_data_8JEN_H, lw=5, color="#f46652")
plt.plot(time_ns_8jen_I, smooth_data_8JEN_I, lw=5, color="#f46652")
plt.plot(time_ns_8jen_J, smooth_data_8JEN_J, lw=5, color="#f46652")

smooth_data_8JEL_C = np.convolve(rmsd_8jel_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_F = np.convolve(rmsd_8jel_Chain_F.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_I = np.convolve(rmsd_8jel_Chain_I.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_L = np.convolve(rmsd_8jel_Chain_L.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jel_C, smooth_data_8JEL_C, lw=5, color="#af97fa", label="8JEL")
plt.plot(time_ns_8jel_F, smooth_data_8JEL_F, lw=5, color="#af97fa")
plt.plot(time_ns_8jel_I, smooth_data_8JEL_I, lw=5, color="#af97fa")
plt.plot(time_ns_8jel_L, smooth_data_8JEL_L, lw=5, color="#af97fa")

plt.ylim(0, 6)
plt.xlim(5, 495)

plt.legend()
plt.ylabel('RMSD (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Time (ns)', fontsize=14, fontweight="bold")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSD (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSD.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(time_ns_3rq3_B, smooth_data_3RQ3_B, lw=5, color="red", label="None")
plt.plot(time_ns_3rq3_A, smooth_data_3RQ3_A, lw=5, color="red")

plt.plot(time_ns_3q0h_A, smooth_data_3Q0H_A, lw=5, color="red")
plt.plot(time_ns_3q0h_B, smooth_data_3Q0H_B, lw=5, color="red")

plt.plot(time_ns_3udw_A, smooth_data_3UDW_A, lw=5, color="#006a8b", label="Biological Receptor")
plt.plot(time_ns_3udw_B, smooth_data_3UDW_B, lw=5, color="#006a8b")

plt.plot(time_ns_3ucr_C, smooth_data_3UCR_C, lw=5, color="red")
plt.plot(time_ns_3ucr_D, smooth_data_3UCR_D, lw=5, color="red")
plt.plot(time_ns_3ucr_B, smooth_data_3UCR_B, lw=5, color="red")
plt.plot(time_ns_3ucr_A, smooth_data_3UCR_A, lw=5, color="red")

plt.plot(time_ns_5v52_A, smooth_data_5V52_A, lw=5, color="#006a8b")
plt.plot(time_ns_5v52_B, smooth_data_5V52_B, lw=5, color="#006a8b")

plt.plot(time_ns_7vyt_A, smooth_data_7VYT_A, lw=5, color="grey", label="Antibody")
plt.plot(time_ns_7vyt_C, smooth_data_7VYT_C, lw=5, color="grey")

plt.plot(time_ns_8szy_E, smooth_data_8SZY_E, lw=5, color="grey")
plt.plot(time_ns_8szy_J, smooth_data_8SZY_J, lw=5, color="grey")

plt.plot(time_ns_8jeo_A, smooth_data_8JEO_A, lw=5, color="grey")
plt.plot(time_ns_8jeo_D, smooth_data_8JEO_D, lw=5, color="grey")

plt.plot(time_ns_8jen_G, smooth_data_8JEN_G, lw=5, color="grey")
plt.plot(time_ns_8jen_H, smooth_data_8JEN_H, lw=5, color="grey")
plt.plot(time_ns_8jen_I, smooth_data_8JEN_I, lw=5, color="grey")
plt.plot(time_ns_8jen_J, smooth_data_8JEN_J, lw=5, color="grey")

plt.plot(time_ns_8jel_C, smooth_data_8JEL_C, lw=5, color="grey")
plt.plot(time_ns_8jel_F, smooth_data_8JEL_F, lw=5, color="grey")
plt.plot(time_ns_8jel_I, smooth_data_8JEL_I, lw=5, color="grey")
plt.plot(time_ns_8jel_J, smooth_data_8JEL_J, lw=5, color="grey")

plt.ylim(0, 6)
plt.xlim(5, 495)

plt.legend()
plt.ylabel('RMSD (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Time (ns)', fontsize=14, fontweight="bold")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSD (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSD_AntibodyBiologicalReceptor.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(time_ns_3rq3_B, smooth_data_3RQ3_B, lw=5, color="orange", label="Dimer")
plt.plot(time_ns_3rq3_A, smooth_data_3RQ3_A, lw=5, color="orange")

plt.plot(time_ns_3q0h_A, smooth_data_3Q0H_A, lw=5, color="orange")
plt.plot(time_ns_3q0h_B, smooth_data_3Q0H_B, lw=5, color="orange")

plt.plot(time_ns_3udw_A, smooth_data_3UDW_A, lw=5, color="orange")
plt.plot(time_ns_3udw_B, smooth_data_3UDW_B, lw=5, color="orange")

plt.plot(time_ns_3ucr_C, smooth_data_3UCR_C, lw=5, color="#b27100", label="Tetramer")
plt.plot(time_ns_3ucr_D, smooth_data_3UCR_D, lw=5, color="#b27100")
plt.plot(time_ns_3ucr_B, smooth_data_3UCR_B, lw=5, color="#b27100")
plt.plot(time_ns_3ucr_A, smooth_data_3UCR_A, lw=5, color="#b27100")

plt.plot(time_ns_5v52_A, smooth_data_5V52_A, lw=5, color="orange")
plt.plot(time_ns_5v52_B, smooth_data_5V52_B, lw=5, color="orange")

plt.plot(time_ns_7vyt_A, smooth_data_7VYT_A, lw=5, color="orange")
plt.plot(time_ns_7vyt_C, smooth_data_7VYT_C, lw=5, color="orange")

plt.plot(time_ns_8szy_E, smooth_data_8SZY_E, lw=5, color="orange")
plt.plot(time_ns_8szy_J, smooth_data_8SZY_J, lw=5, color="orange")

plt.plot(time_ns_8jeo_A, smooth_data_8JEO_A, lw=5, color="orange")
plt.plot(time_ns_8jeo_D, smooth_data_8JEO_D, lw=5, color="orange")

plt.plot(time_ns_8jen_G, smooth_data_8JEN_G, lw=5, color="orange")
plt.plot(time_ns_8jen_H, smooth_data_8JEN_H, lw=5, color="orange")
plt.plot(time_ns_8jen_I, smooth_data_8JEN_I, lw=5, color="orange")
plt.plot(time_ns_8jen_J, smooth_data_8JEN_J, lw=5, color="orange")

plt.plot(time_ns_8jel_C, smooth_data_8JEL_C, lw=5, color="orange")
plt.plot(time_ns_8jel_F, smooth_data_8JEL_F, lw=5, color="orange")
plt.plot(time_ns_8jel_I, smooth_data_8JEL_I, lw=5, color="orange")
plt.plot(time_ns_8jel_J, smooth_data_8JEL_J, lw=5, color="orange")

plt.ylim(0, 6)
plt.xlim(5, 495)

plt.legend()
plt.ylabel('RMSD (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Time (ns)', fontsize=14, fontweight="bold")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSD (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSD_DimerTetramer.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
residues_list = np.load("residues_list.npy")

# %%
residues_list
# Out:
# array(['MET/HIS-21', 'MET/HIS-22', 'MET-23', 'THR-24', 'GLY-25', 'THR-26',
#        'ILE-27', 'GLU-28', 'THR-29', 'THR-30', 'GLY-31', 'ASN-32',
#        'ILE-33', 'SER-34', 'ALA-35', 'GLU-36', 'LYS-37', 'GLY-38',
#        'GLY-39', 'SER-40', 'ILE-41', 'ILE-42', 'LEU-43', 'GLN-44',
#        'CYS-45', 'HIS-46', 'LEU-47', 'SER-48', 'SER-49', 'THR-50',
#        'THR-51', 'ALA-52', 'GLN-53', 'VAL-54', 'THR-55', 'GLN-56',
#        'VAL-57', 'ASN-58', 'TRP-59', 'GLU-60', 'GLN-61', 'GLN-62',
#        'ASP-63', 'GLN-64', 'LEU-65', 'LEU-66', 'ALA-67', 'ILE-68',
#        'CYS/SER-69', 'ASN-70', 'ALA-71', 'ASP-72', 'LEU-73', 'GLY-74',
#        'TRP-75', 'HIS-76', 'ILE-77', 'SER-78', 'PRO-79', 'SER-80',
#        'PHE-81', 'LYS-82', 'ASP-83', 'ARG-84', 'VAL-85', 'ALA-86',
#        'PRO-87', 'GLY-88', 'PRO-89', 'GLY-90', 'LEU-91', 'GLY-92',
#        'LEU-93', 'THR-94', 'LEU-95', 'GLN-96', 'SER-97', 'LEU-98',
#        'THR-99', 'VAL-100', 'ASN-101', 'ASP-102', 'THR-103', 'GLY-104',
# ...

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(residues_list[:-2], rmsfer_3q0h_Chain_A.results.rmsf, color="#006a8b", label="3Q0H")
plt.plot(residues_list[4:], rmsfer_3q0h_Chain_B.results.rmsf, color="#006a8b") 

plt.plot(residues_list[2:-2], rmsfer_3rq3_Chain_B.results.rmsf, color="red", label="3RQ3")
plt.plot(residues_list[1:-3], rmsfer_3rq3_Chain_A.results.rmsf, color="red")

plt.plot(residues_list[2:-4], rmsfer_3udw_Chain_A.results.rmsf, color="green", label="3UDW")
plt.plot(residues_list[3:-5], rmsfer_3udw_Chain_B.results.rmsf, color="green")

plt.plot(residues_list[:-3], rmsfer_3ucr_Chain_C.results.rmsf, color="orange", label="3UCR")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_D.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_B.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_A.results.rmsf, color="orange")

plt.plot(residues_list[3:-5], rmsfer_5v52_Chain_A.results.rmsf, color="#b27100", label="5V52")
plt.plot(residues_list[3:-4], rmsfer_5v52_Chain_B.results.rmsf, color="#b27100")

plt.plot(residues_list[4:-2], rmsfer_7vyt_Chain_A.results.rmsf, color="grey", label="7VYT")
plt.plot(residues_list[4:-3], rmsfer_7vyt_Chain_C.results.rmsf, color="grey")

plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_E.results.rmsf, color="#01ab82", label="8SZY")
plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_J.results.rmsf, color="#01ab82")

plt.plot(residues_list[1:-3], rmsfer_8jeo_Chain_D.results.rmsf, color="#6f5602", label="8JEO")
plt.plot(residues_list[2:-3], rmsfer_8jeo_Chain_A.results.rmsf, color="#6f5602")

plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_G.results.rmsf, color="#6f5602", label="8JEN")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_H.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_I.results.rmsf, color="#6f5602")
plt.plot(residues_list[4:-3], rmsfer_8jen_Chain_J.results.rmsf, color="#6f5602")

plt.plot(residues_list[1:-2], rmsfer_8jel_Chain_C.results.rmsf, color="#6f5602", label="8JEL")
plt.plot(residues_list[2:-1], rmsfer_8jel_Chain_F.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-2], rmsfer_8jel_Chain_I.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-3], rmsfer_8jel_Chain_L.results.rmsf, color="#6f5602")

# # Define the x range
# x = [0, 110]  # For example, from 0 to 10
# y = [4, 4]   # y is always 4, creating a horizontal line

# # Plot the line
# plt.plot(x, y, color='black')

plt.axvspan(15, 17, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(28, 31, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(41, 43, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(49.5, 53.5, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(56.5, 63, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(76.5, 82, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(92, 94.5, zorder=0, alpha=0.2, color='#D09005', label='Highest deviations')

plt.axvspan(46, 53, ymax=0.05, zorder=0, alpha=1, color='#000000')
plt.axvspan(33, 35, ymax=0.05, zorder=0, alpha=1, color='#000000', label="Binding pocket")
plt.axvspan(91, 93, ymax=0.05, zorder=0, alpha=1, color='#000000')

plt.axvspan(34.5, 35.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(36.5, 37.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(38.5, 39.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602', label="Important residues for interactions")
plt.axvspan(43.5, 44.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(46.5, 47.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(48.5, 49.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(51.5, 52.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(54.5, 55.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(60.5, 61.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(91.5, 92.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')

plt.ylim(0, 10)

plt.legend()
plt.ylabel('RMSF (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Residues', fontsize=14, fontweight="bold")
plt.xticks(fontsize=6, rotation=90)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSF (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSF.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(residues_list[:-2], rmsfer_3q0h_Chain_A.results.rmsf, color="red", label="None")
plt.plot(residues_list[4:], rmsfer_3q0h_Chain_B.results.rmsf, color="red") 

plt.plot(residues_list[2:-2], rmsfer_3rq3_Chain_B.results.rmsf, color="red")
plt.plot(residues_list[1:-3], rmsfer_3rq3_Chain_A.results.rmsf, color="red")

plt.plot(residues_list[2:-4], rmsfer_3udw_Chain_A.results.rmsf, color="#006a8b", label="Biological Receptor")
plt.plot(residues_list[3:-5], rmsfer_3udw_Chain_B.results.rmsf, color="#006a8b")

plt.plot(residues_list[:-3], rmsfer_3ucr_Chain_C.results.rmsf, color="red")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_D.results.rmsf, color="red")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_B.results.rmsf, color="red")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_A.results.rmsf, color="red")

plt.plot(residues_list[3:-5], rmsfer_5v52_Chain_A.results.rmsf, color="#006a8b")
plt.plot(residues_list[3:-4], rmsfer_5v52_Chain_B.results.rmsf, color="#006a8b")

plt.plot(residues_list[4:-2], rmsfer_7vyt_Chain_A.results.rmsf, color="grey", label="Antibody")
plt.plot(residues_list[4:-3], rmsfer_7vyt_Chain_C.results.rmsf, color="grey")

plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_E.results.rmsf, color="grey")
plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_J.results.rmsf, color="grey")

plt.plot(residues_list[1:-3], rmsfer_8jeo_Chain_D.results.rmsf, color="grey")
plt.plot(residues_list[2:-3], rmsfer_8jeo_Chain_A.results.rmsf, color="grey")

plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_G.results.rmsf, color="grey")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_H.results.rmsf, color="grey")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_I.results.rmsf, color="grey")
plt.plot(residues_list[4:-3], rmsfer_8jen_Chain_J.results.rmsf, color="grey")

plt.plot(residues_list[1:-2], rmsfer_8jel_Chain_C.results.rmsf, color="grey")
plt.plot(residues_list[2:-1], rmsfer_8jel_Chain_F.results.rmsf, color="grey")
plt.plot(residues_list[2:-2], rmsfer_8jel_Chain_I.results.rmsf, color="grey")
plt.plot(residues_list[2:-3], rmsfer_8jel_Chain_L.results.rmsf, color="grey")

# # Define the x range
# x = [0, 110]  # For example, from 0 to 10
# y = [4, 4]   # y is always 4, creating a horizontal line

# # Plot the line
# plt.plot(x, y, color='black')

plt.axvspan(15, 17, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(28, 31, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(41, 43, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(49.5, 53.5, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(56.5, 63, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(76.5, 82, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(92, 94.5, zorder=0, alpha=0.2, color='#D09005', label='Highest deviations')

plt.axvspan(46, 53, ymax=0.05, zorder=0, alpha=1, color='#000000')
plt.axvspan(33, 35, ymax=0.05, zorder=0, alpha=1, color='#000000', label="Binding pocket")
plt.axvspan(91, 93, ymax=0.05, zorder=0, alpha=1, color='#000000')

plt.axvspan(34.5, 35.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(36.5, 37.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(38.5, 39.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602', label="Important residues for interactions")
plt.axvspan(43.5, 44.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(46.5, 47.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(48.5, 49.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(51.5, 52.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(54.5, 55.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(60.5, 61.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(91.5, 92.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')

plt.ylim(0, 10)

plt.legend()
plt.ylabel('RMSF (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Residues', fontsize=14, fontweight="bold")
plt.xticks(fontsize=6, rotation=90)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSF (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSF_AntibodyBiologicalReceptor.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(residues_list[:-2], rmsfer_3q0h_Chain_A.results.rmsf, color="orange", label="Dimer")
plt.plot(residues_list[4:], rmsfer_3q0h_Chain_B.results.rmsf, color="orange") 

plt.plot(residues_list[2:-2], rmsfer_3rq3_Chain_B.results.rmsf, color="orange")
plt.plot(residues_list[1:-3], rmsfer_3rq3_Chain_A.results.rmsf, color="orange")

plt.plot(residues_list[2:-4], rmsfer_3udw_Chain_A.results.rmsf, color="orange")
plt.plot(residues_list[3:-5], rmsfer_3udw_Chain_B.results.rmsf, color="orange")

plt.plot(residues_list[:-3], rmsfer_3ucr_Chain_C.results.rmsf, color="#b27100", label="Tetramer")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_D.results.rmsf, color="#b27100")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_B.results.rmsf, color="#b27100")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_A.results.rmsf, color="#b27100")

plt.plot(residues_list[3:-5], rmsfer_5v52_Chain_A.results.rmsf, color="orange")
plt.plot(residues_list[3:-4], rmsfer_5v52_Chain_B.results.rmsf, color="orange")

plt.plot(residues_list[4:-2], rmsfer_7vyt_Chain_A.results.rmsf, color="orange")
plt.plot(residues_list[4:-3], rmsfer_7vyt_Chain_C.results.rmsf, color="orange")

plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_E.results.rmsf, color="orange")
plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_J.results.rmsf, color="orange")

plt.plot(residues_list[1:-3], rmsfer_8jeo_Chain_D.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_8jeo_Chain_A.results.rmsf, color="orange")

plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_G.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_H.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_I.results.rmsf, color="orange")
plt.plot(residues_list[4:-3], rmsfer_8jen_Chain_J.results.rmsf, color="orange")

plt.plot(residues_list[1:-2], rmsfer_8jel_Chain_C.results.rmsf, color="orange")
plt.plot(residues_list[2:-1], rmsfer_8jel_Chain_F.results.rmsf, color="orange")
plt.plot(residues_list[2:-2], rmsfer_8jel_Chain_I.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_8jel_Chain_L.results.rmsf, color="orange")

# # Define the x range
# x = [0, 110]  # For example, from 0 to 10
# y = [4, 4]   # y is always 4, creating a horizontal line

# # Plot the line
# plt.plot(x, y, color='black')

plt.axvspan(15, 17, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(28, 31, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(41, 43, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(49.5, 53.5, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(56.5, 63, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(76.5, 82, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(92, 94.5, zorder=0, alpha=0.2, color='#D09005', label='Highest deviations')

plt.axvspan(46, 53, ymax=0.05, zorder=0, alpha=1, color='#000000')
plt.axvspan(33, 35, ymax=0.05, zorder=0, alpha=1, color='#000000', label="Binding pocket")
plt.axvspan(91, 93, ymax=0.05, zorder=0, alpha=1, color='#000000')

plt.axvspan(34.5, 35.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(36.5, 37.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(38.5, 39.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602', label="Important residues for interactions")
plt.axvspan(43.5, 44.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(46.5, 47.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(48.5, 49.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(51.5, 52.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(54.5, 55.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(60.5, 61.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(91.5, 92.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')

plt.ylim(0, 10)

plt.legend()
plt.ylabel('RMSF (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Residues', fontsize=14, fontweight="bold")
plt.xticks(fontsize=6, rotation=90)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSF (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSF_DimerTetramer.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

#plt.plot(time_ns_3rq3_B, rmsd_3rq3_Chain_B.results.rmsd[:,2], color="red", label="3RQ3")
#plt.plot(time_ns_3rq3_A, rmsd_3rq3_Chain_A.results.rmsd[:,2], color="red")

# Apply smoothing using convolution
window_size = 500
smooth_data_3RQ3_B = np.convolve(rmsd_3rq3_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3RQ3_A = np.convolve(rmsd_3rq3_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
# Plot smoothed data
plt.plot(time_ns_3rq3_B, smooth_data_3RQ3_B, lw=5, color="red", label="3RQ3")
plt.plot(time_ns_3rq3_A, smooth_data_3RQ3_A, lw=5, color="red")

#plt.plot(time_ns_3q0h_A, rmsd_3q0h_Chain_A.results.rmsd[:,2], color="#006a8b", label="3Q0H")
#plt.plot(time_ns_3q0h_B, rmsd_3q0h_Chain_B.results.rmsd[:,2], color="#006a8b")

smooth_data_3Q0H_A = np.convolve(rmsd_3q0h_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3Q0H_B = np.convolve(rmsd_3q0h_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3q0h_A, smooth_data_3Q0H_A, lw=5, color="#006a8b", label="3Q0H")
plt.plot(time_ns_3q0h_B, smooth_data_3Q0H_B, lw=5, color="#006a8b")

#plt.plot(time_ns_3ucr_C, rmsd_3ucr_Chain_C.results.rmsd[:,2], color="orange", label="3UCR")
#plt.plot(time_ns_3ucr_D, rmsd_3ucr_Chain_D.results.rmsd[:,2], color="orange")
#plt.plot(time_ns_3ucr_B, rmsd_3ucr_Chain_B.results.rmsd[:,2], color="orange")
#plt.plot(time_ns_3ucr_A, rmsd_3ucr_Chain_A.results.rmsd[:,2], color="orange")

smooth_data_3UCR_C = np.convolve(rmsd_3ucr_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UCR_D = np.convolve(rmsd_3ucr_Chain_D.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UCR_B = np.convolve(rmsd_3ucr_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UCR_A = np.convolve(rmsd_3ucr_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3ucr_C, smooth_data_3UCR_C, lw=5, color="orange", label="3UCR")
plt.plot(time_ns_3ucr_D, smooth_data_3UCR_D, lw=5, color="orange")
plt.plot(time_ns_3ucr_B, smooth_data_3UCR_B, lw=5, color="orange")
plt.plot(time_ns_3ucr_A, smooth_data_3UCR_A, lw=5, color="orange")

plt.ylim(0, 6)
plt.xlim(5, 495)

plt.legend()
plt.ylabel('RMSD (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Time (ns)', fontsize=14, fontweight="bold")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSD (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSD_WithNoLigands.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

#plt.plot(time_ns_3rq3_B, rmsd_3rq3_Chain_B.results.rmsd[:,2], color="red", label="3RQ3")
#plt.plot(time_ns_3rq3_A, rmsd_3rq3_Chain_A.results.rmsd[:,2], color="red")

# Apply smoothing using convolution
window_size = 500

#plt.plot(time_ns_3udw_A, rmsd_3udw_Chain_A.results.rmsd[:,2], color="green", label="3UDW")
#plt.plot(time_ns_3udw_B, rmsd_3udw_Chain_B.results.rmsd[:,2], color="green")

smooth_data_3UDW_A = np.convolve(rmsd_3udw_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UDW_B = np.convolve(rmsd_3udw_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3udw_A, smooth_data_3UDW_A, lw=5, color="green", label="3UDW")
plt.plot(time_ns_3udw_B, smooth_data_3UDW_B, lw=5, color="green")

#plt.plot(time_ns_5v52_A, rmsd_5v52_Chain_A.results.rmsd[:,2], color="#b27100", label="5V52")
#plt.plot(time_ns_5v52_B, rmsd_5v52_Chain_B.results.rmsd[:,2], color="#b27100")

smooth_data_5V52_A = np.convolve(rmsd_5v52_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_5V52_B = np.convolve(rmsd_5v52_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_5v52_A, smooth_data_5V52_A, lw=5, color="#b27100", label="5V52")
plt.plot(time_ns_5v52_B, smooth_data_5V52_B, lw=5, color="#b27100")

#plt.plot(time_ns_7vyt_A, rmsd_7vyt_Chain_A.results.rmsd[:,2], color="grey", label="7VYT")
#plt.plot(time_ns_7vyt_C, rmsd_7vyt_Chain_C.results.rmsd[:,2], color="grey")

smooth_data_7VYT_A = np.convolve(rmsd_7vyt_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_7VYT_C = np.convolve(rmsd_7vyt_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_7vyt_A, smooth_data_7VYT_A, lw=5, color="grey", label="7VYT")
plt.plot(time_ns_7vyt_C, smooth_data_7VYT_C, lw=5, color="grey")

#plt.plot(time_ns_8szy_E, rmsd_8szy_Chain_E.results.rmsd[:,2], color="#01ab82", label="8SZY")
#plt.plot(time_ns_8szy_J, rmsd_8szy_Chain_J.results.rmsd[:,2], color="#01ab82")

smooth_data_8SZY_E = np.convolve(rmsd_8szy_Chain_E.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8SZY_J = np.convolve(rmsd_8szy_Chain_J.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8szy_E, smooth_data_8SZY_E, lw=5, color="#01ab82", label="8SZY")
plt.plot(time_ns_8szy_J, smooth_data_8SZY_J, lw=5, color="#01ab82")

smooth_data_8JEO_A = np.convolve(rmsd_8jeo_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEO_D = np.convolve(rmsd_8jeo_Chain_D.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jeo_A, smooth_data_8JEO_A, lw=5, color="#6f5602", label="8JEO")
plt.plot(time_ns_8jeo_D, smooth_data_8JEO_D, lw=5, color="#6f5602")

smooth_data_8JEN_G = np.convolve(rmsd_8jen_Chain_G.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_H = np.convolve(rmsd_8jen_Chain_H.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_I = np.convolve(rmsd_8jen_Chain_I.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_J = np.convolve(rmsd_8jen_Chain_J.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jen_G, smooth_data_8JEN_G, lw=5, color="#f46652", label="8JEN")
plt.plot(time_ns_8jen_H, smooth_data_8JEN_H, lw=5, color="#f46652")
plt.plot(time_ns_8jen_I, smooth_data_8JEN_I, lw=5, color="#f46652")
plt.plot(time_ns_8jen_J, smooth_data_8JEN_J, lw=5, color="#f46652")

smooth_data_8JEL_C = np.convolve(rmsd_8jel_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_F = np.convolve(rmsd_8jel_Chain_F.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_I = np.convolve(rmsd_8jel_Chain_I.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_L = np.convolve(rmsd_8jel_Chain_L.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jel_C, smooth_data_8JEL_C, lw=5, color="#af97fa", label="8JEL")
plt.plot(time_ns_8jel_F, smooth_data_8JEL_F, lw=5, color="#af97fa")
plt.plot(time_ns_8jel_I, smooth_data_8JEL_I, lw=5, color="#af97fa")
plt.plot(time_ns_8jel_L, smooth_data_8JEL_L, lw=5, color="#af97fa")

plt.ylim(0, 6)
plt.xlim(5, 495)

plt.legend()
plt.ylabel('RMSD (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Time (ns)', fontsize=14, fontweight="bold")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSD (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSD_WithLigands.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
# RMSDs
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

#plt.plot(time_ns_3rq3_B, rmsd_3rq3_Chain_B.results.rmsd[:,2], color="red", label="3RQ3")
#plt.plot(time_ns_3rq3_A, rmsd_3rq3_Chain_A.results.rmsd[:,2], color="red")

# Apply smoothing using convolution
window_size = 500
smooth_data_3RQ3_B = np.convolve(rmsd_3rq3_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3RQ3_A = np.convolve(rmsd_3rq3_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
# Plot smoothed data
plt.plot(time_ns_3rq3_B, smooth_data_3RQ3_B, lw=5, color="red", label="3RQ3")
plt.plot(time_ns_3rq3_A, smooth_data_3RQ3_A, lw=5, color="red")

#plt.plot(time_ns_3q0h_A, rmsd_3q0h_Chain_A.results.rmsd[:,2], color="#006a8b", label="3Q0H")
#plt.plot(time_ns_3q0h_B, rmsd_3q0h_Chain_B.results.rmsd[:,2], color="#006a8b")

smooth_data_3Q0H_A = np.convolve(rmsd_3q0h_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3Q0H_B = np.convolve(rmsd_3q0h_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3q0h_A, smooth_data_3Q0H_A, lw=5, color="#006a8b", label="3Q0H")
plt.plot(time_ns_3q0h_B, smooth_data_3Q0H_B, lw=5, color="#006a8b")

#plt.plot(time_ns_3udw_A, rmsd_3udw_Chain_A.results.rmsd[:,2], color="green", label="3UDW")
#plt.plot(time_ns_3udw_B, rmsd_3udw_Chain_B.results.rmsd[:,2], color="green")

smooth_data_3UDW_A = np.convolve(rmsd_3udw_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_3UDW_B = np.convolve(rmsd_3udw_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_3udw_A, smooth_data_3UDW_A, lw=5, color="green", label="3UDW")
plt.plot(time_ns_3udw_B, smooth_data_3UDW_B, lw=5, color="green")

#plt.plot(time_ns_5v52_A, rmsd_5v52_Chain_A.results.rmsd[:,2], color="#b27100", label="5V52")
#plt.plot(time_ns_5v52_B, rmsd_5v52_Chain_B.results.rmsd[:,2], color="#b27100")

smooth_data_5V52_A = np.convolve(rmsd_5v52_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_5V52_B = np.convolve(rmsd_5v52_Chain_B.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_5v52_A, smooth_data_5V52_A, lw=5, color="#b27100", label="5V52")
plt.plot(time_ns_5v52_B, smooth_data_5V52_B, lw=5, color="#b27100")

#plt.plot(time_ns_7vyt_A, rmsd_7vyt_Chain_A.results.rmsd[:,2], color="grey", label="7VYT")
#plt.plot(time_ns_7vyt_C, rmsd_7vyt_Chain_C.results.rmsd[:,2], color="grey")

smooth_data_7VYT_A = np.convolve(rmsd_7vyt_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_7VYT_C = np.convolve(rmsd_7vyt_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_7vyt_A, smooth_data_7VYT_A, lw=5, color="grey", label="7VYT")
plt.plot(time_ns_7vyt_C, smooth_data_7VYT_C, lw=5, color="grey")

#plt.plot(time_ns_8szy_E, rmsd_8szy_Chain_E.results.rmsd[:,2], color="#01ab82", label="8SZY")
#plt.plot(time_ns_8szy_J, rmsd_8szy_Chain_J.results.rmsd[:,2], color="#01ab82")

smooth_data_8SZY_E = np.convolve(rmsd_8szy_Chain_E.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8SZY_J = np.convolve(rmsd_8szy_Chain_J.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8szy_E, smooth_data_8SZY_E, lw=5, color="#01ab82", label="8SZY")
plt.plot(time_ns_8szy_J, smooth_data_8SZY_J, lw=5, color="#01ab82")

smooth_data_8JEO_A = np.convolve(rmsd_8jeo_Chain_A.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEO_D = np.convolve(rmsd_8jeo_Chain_D.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jeo_A, smooth_data_8JEO_A, lw=5, color="#6f5602", label="8JEO")
plt.plot(time_ns_8jeo_D, smooth_data_8JEO_D, lw=5, color="#6f5602")

smooth_data_8JEN_G = np.convolve(rmsd_8jen_Chain_G.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_H = np.convolve(rmsd_8jen_Chain_H.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_I = np.convolve(rmsd_8jen_Chain_I.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEN_J = np.convolve(rmsd_8jen_Chain_J.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jen_G, smooth_data_8JEN_G, lw=5, color="#f46652", label="8JEN")
plt.plot(time_ns_8jen_H, smooth_data_8JEN_H, lw=5, color="#f46652")
plt.plot(time_ns_8jen_I, smooth_data_8JEN_I, lw=5, color="#f46652")
plt.plot(time_ns_8jen_J, smooth_data_8JEN_J, lw=5, color="#f46652")

smooth_data_8JEL_C = np.convolve(rmsd_8jel_Chain_C.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_F = np.convolve(rmsd_8jel_Chain_F.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_I = np.convolve(rmsd_8jel_Chain_I.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
smooth_data_8JEL_L = np.convolve(rmsd_8jel_Chain_L.results.rmsd[:,2], np.ones(window_size)/window_size, mode="same")
plt.plot(time_ns_8jel_C, smooth_data_8JEL_C, lw=5, color="#af97fa", label="8JEL")
plt.plot(time_ns_8jel_F, smooth_data_8JEL_F, lw=5, color="#af97fa")
plt.plot(time_ns_8jel_I, smooth_data_8JEL_I, lw=5, color="#af97fa")
plt.plot(time_ns_8jel_L, smooth_data_8JEL_L, lw=5, color="#af97fa")

plt.ylim(0, 6)
plt.xlim(5, 495)

plt.legend()
plt.ylabel('RMSD (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Time (ns)', fontsize=14, fontweight="bold")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSD (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSD_Dimers.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(residues_list[:-2], rmsfer_3q0h_Chain_A.results.rmsf, color="#006a8b", label="3Q0H")
plt.plot(residues_list[4:], rmsfer_3q0h_Chain_B.results.rmsf, color="#006a8b") 

plt.plot(residues_list[2:-2], rmsfer_3rq3_Chain_B.results.rmsf, color="red", label="3RQ3")
plt.plot(residues_list[1:-3], rmsfer_3rq3_Chain_A.results.rmsf, color="red")

plt.plot(residues_list[:-3], rmsfer_3ucr_Chain_C.results.rmsf, color="orange", label="3UCR")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_D.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_B.results.rmsf, color="orange")
plt.plot(residues_list[2:-3], rmsfer_3ucr_Chain_A.results.rmsf, color="orange")

plt.axvspan(15, 17, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(28, 31, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(41, 43, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(49.5, 53.5, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(56.5, 63, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(76.5, 82, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(92, 94.5, zorder=0, alpha=0.2, color='#D09005', label='Highest deviations')

plt.axvspan(46, 53, ymax=0.05, zorder=0, alpha=1, color='#000000')
plt.axvspan(33, 35, ymax=0.05, zorder=0, alpha=1, color='#000000', label="Binding pocket")
plt.axvspan(91, 93, ymax=0.05, zorder=0, alpha=1, color='#000000')

plt.axvspan(34.5, 35.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(36.5, 37.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(38.5, 39.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602', label="Important residues for interactions")
plt.axvspan(43.5, 44.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(46.5, 47.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(48.5, 49.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(51.5, 52.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(54.5, 55.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(60.5, 61.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(91.5, 92.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')

plt.ylim(0, 10)

plt.legend()
plt.ylabel('RMSF (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Residues', fontsize=14, fontweight="bold")
plt.xticks(fontsize=6, rotation=90)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSF (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSF_WithNoLigands.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(residues_list[1:-3], rmsfer_8jeo_Chain_D.results.rmsf, color="#6f5602", label="8JEO")
plt.plot(residues_list[2:-3], rmsfer_8jeo_Chain_A.results.rmsf, color="#6f5602")

plt.plot(residues_list[2:-4], rmsfer_3udw_Chain_A.results.rmsf, color="green", label="3UDW")
plt.plot(residues_list[3:-5], rmsfer_3udw_Chain_B.results.rmsf, color="green")

plt.plot(residues_list[3:-5], rmsfer_5v52_Chain_A.results.rmsf, color="#b27100", label="5V52")
plt.plot(residues_list[3:-4], rmsfer_5v52_Chain_B.results.rmsf, color="#b27100")

plt.plot(residues_list[4:-2], rmsfer_7vyt_Chain_A.results.rmsf, color="grey", label="7VYT")
plt.plot(residues_list[4:-3], rmsfer_7vyt_Chain_C.results.rmsf, color="grey")

plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_E.results.rmsf, color="#01ab82", label="8SZY")
plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_J.results.rmsf, color="#01ab82")

plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_G.results.rmsf, color="#6f5602", label="8JEN")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_H.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_I.results.rmsf, color="#6f5602")
plt.plot(residues_list[4:-3], rmsfer_8jen_Chain_J.results.rmsf, color="#6f5602")

plt.plot(residues_list[1:-2], rmsfer_8jel_Chain_C.results.rmsf, color="#6f5602", label="8JEL")
plt.plot(residues_list[2:-1], rmsfer_8jel_Chain_F.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-2], rmsfer_8jel_Chain_I.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-3], rmsfer_8jel_Chain_L.results.rmsf, color="#6f5602")



# # Define the x range
# x = [0, 110]  # For example, from 0 to 10
# y = [4, 4]   # y is always 4, creating a horizontal line

# # Plot the line
# plt.plot(x, y, color='black')

plt.axvspan(15, 17, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(28, 31, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(41, 43, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(49.5, 53.5, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(56.5, 63, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(76.5, 82, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(92, 94.5, zorder=0, alpha=0.2, color='#D09005', label='Highest deviations')

plt.axvspan(46, 53, ymax=0.05, zorder=0, alpha=1, color='#000000')
plt.axvspan(33, 35, ymax=0.05, zorder=0, alpha=1, color='#000000', label="Binding pocket")
plt.axvspan(91, 93, ymax=0.05, zorder=0, alpha=1, color='#000000')

plt.axvspan(34.5, 35.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(36.5, 37.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(38.5, 39.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602', label="Important residues for interactions")
plt.axvspan(43.5, 44.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(46.5, 47.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(48.5, 49.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(51.5, 52.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(54.5, 55.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(60.5, 61.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(91.5, 92.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')

plt.ylim(0, 10)

plt.legend()
plt.ylabel('RMSF (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Residues', fontsize=14, fontweight="bold")
plt.xticks(fontsize=6, rotation=90)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSF (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSF_WithLigands.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.rcParams["font.family"] = "monospace"  # Text font

border_linewidth = 2  # Adjust the linewidth as needed
plt.gca().spines['top'].set_visible(True)
plt.gca().spines['right'].set_visible(True)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)
plt.gca().spines['top'].set_linewidth(border_linewidth)
plt.gca().spines['right'].set_linewidth(border_linewidth)
plt.gca().spines['bottom'].set_linewidth(border_linewidth)
plt.gca().spines['left'].set_linewidth(border_linewidth)

plt.plot(residues_list[:-2], rmsfer_3q0h_Chain_A.results.rmsf, color="#006a8b", label="3Q0H")
plt.plot(residues_list[4:], rmsfer_3q0h_Chain_B.results.rmsf, color="#006a8b") 

plt.plot(residues_list[2:-2], rmsfer_3rq3_Chain_B.results.rmsf, color="red", label="3RQ3")
plt.plot(residues_list[1:-3], rmsfer_3rq3_Chain_A.results.rmsf, color="red")

plt.plot(residues_list[2:-4], rmsfer_3udw_Chain_A.results.rmsf, color="green", label="3UDW")
plt.plot(residues_list[3:-5], rmsfer_3udw_Chain_B.results.rmsf, color="green")

plt.plot(residues_list[3:-5], rmsfer_5v52_Chain_A.results.rmsf, color="#b27100", label="5V52")
plt.plot(residues_list[3:-4], rmsfer_5v52_Chain_B.results.rmsf, color="#b27100")

plt.plot(residues_list[4:-2], rmsfer_7vyt_Chain_A.results.rmsf, color="grey", label="7VYT")
plt.plot(residues_list[4:-3], rmsfer_7vyt_Chain_C.results.rmsf, color="grey")

plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_E.results.rmsf, color="#01ab82", label="8SZY")
plt.plot(residues_list[4:-4], rmsfer_8szy_Chain_J.results.rmsf, color="#01ab82")

plt.plot(residues_list[1:-3], rmsfer_8jeo_Chain_D.results.rmsf, color="#6f5602", label="8JEO")
plt.plot(residues_list[2:-3], rmsfer_8jeo_Chain_A.results.rmsf, color="#6f5602")

plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_G.results.rmsf, color="#6f5602", label="8JEN")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_H.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-3], rmsfer_8jen_Chain_I.results.rmsf, color="#6f5602")
plt.plot(residues_list[4:-3], rmsfer_8jen_Chain_J.results.rmsf, color="#6f5602")

plt.plot(residues_list[1:-2], rmsfer_8jel_Chain_C.results.rmsf, color="#6f5602", label="8JEL")
plt.plot(residues_list[2:-1], rmsfer_8jel_Chain_F.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-2], rmsfer_8jel_Chain_I.results.rmsf, color="#6f5602")
plt.plot(residues_list[2:-3], rmsfer_8jel_Chain_L.results.rmsf, color="#6f5602")

# # Define the x range
# x = [0, 110]  # For example, from 0 to 10
# y = [4, 4]   # y is always 4, creating a horizontal line

# # Plot the line
# plt.plot(x, y, color='black')

plt.axvspan(15, 17, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(28, 31, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(41, 43, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(49.5, 53.5, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(56.5, 63, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(76.5, 82, zorder=0, alpha=0.2, color='#D09005')
plt.axvspan(92, 94.5, zorder=0, alpha=0.2, color='#D09005', label='Highest deviations')

plt.axvspan(46, 53, ymax=0.05, zorder=0, alpha=1, color='#000000')
plt.axvspan(33, 35, ymax=0.05, zorder=0, alpha=1, color='#000000', label="Binding pocket")
plt.axvspan(91, 93, ymax=0.05, zorder=0, alpha=1, color='#000000')

plt.axvspan(34.5, 35.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(36.5, 37.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(38.5, 39.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602', label="Important residues for interactions")
plt.axvspan(43.5, 44.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(46.5, 47.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(48.5, 49.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(51.5, 52.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(54.5, 55.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(60.5, 61.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')
plt.axvspan(91.5, 92.5, ymax=0.065, zorder=0, alpha=0.5, color='#6f5602')

plt.ylim(0, 10)

plt.legend()
plt.ylabel('RMSF (Å)', fontsize=14,  fontweight="bold")
plt.xlabel('Residues', fontsize=14, fontweight="bold")
plt.xticks(fontsize=6, rotation=90)
plt.yticks(fontsize=12)
plt.title(label="C-α RMSF (Å)", fontsize=20, pad=13)

plt.savefig('TIGIT_Structures_RMSF_Dimers.svg', format='svg', bbox_inches='tight')
plt.show()
